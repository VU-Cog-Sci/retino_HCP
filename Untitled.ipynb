# %%
# General imports
import numpy as np
import os
import glob
import json
import sys
import nibabel as nb
import platform
import ipdb
deb = ipdb.set_trace
opj = os.path.join

# %%
# Get subject number and hemisphere to analyse
subject = '999999'
fit_model = 'gauss'
job_vox = 2500 #int(sys.argv[3])
job_dur_req = 10 #float(sys.argv[4])

# %%
# Load the analysis parameters from json file
with open('settings.json') as f:
    json_s = f.read()
    analysis_info = json.loads(json_s)

# %%
# Define server or cluster settings
if 'lisa' in platform.uname()[1]:
    jobscript_template_file = opj(os.getcwd(),'fit','lisa_jobscript_template.sh')
    base_dir = analysis_info['lisa_cluster_base_folder'] 
    sub_command = 'qsub '
    print('analysis running on lisa')
elif 'aeneas' in platform.uname()[1]:
    jobscript_template_file     =   opj(os.getcwd(),'fit','aeneas_jobscript_template.sh')
    base_dir = analysis_info['aeneas_base_folder'] 
    sub_command = 'sh '
    print('analysis running on aeneas')
elif 'home' in platform.uname()[1]:
    jobscript_template_file     =   opj(os.getcwd(),'fit','local_jobscript_template.sh')
    base_dir = analysis_info['local_base_folder'] 
    sub_command = 'sh '
    print('analysis running on local')

fit_script = 'fit/prf_fit.py'
# Out:
# analysis running on local

# %%
# Create job and log output folders
try:
    os.makedirs(opj(base_dir, 'pp_data', subject, fit_model, 'jobs'))
    os.makedirs(opj(base_dir, 'pp_data', subject, fit_model, 'log_outputs'))
except:
    pass

data = []

# %%
# Determine data to analysed
data_file = '/Users/macbook/disks/ae_Home/hcp_code/tfMRI_RETALL_Atlas_1.6mm_MSMAll_hp2000_clean_sg_psc_all.dtseries.nii'
data = nb.cifti2.cifti2.load(data_file)
data_file_shape = data.shape

# %%
print(data.shape)
# Out:
# (1800, 170494)

# %%
# get idx of non empty voxels

start_idx =  np.arange(0,data_file_shape[1],job_vox)
end_idx = start_idx+job_vox
end_idx[-1] = data_file_shape[1]

print('%i jobs of %1.1fh each will be run/send to %s'%(start_idx.shape[0],job_dur_req,platform.uname()[1]))

job_input = []
for iter_job in np.arange(0,start_idx.shape[0],1):
    job_input = data.get_data()[:,int(start_idx[iter_job]):int(end_idx[iter_job])]

    print('input data vox num: %i to %i'%(int(start_idx[iter_job]),int(end_idx[iter_job])))
    # Define output file
    base_file_name = os.path.split(data_file[0])[-1][:-7]
    opfn = opj(base_dir,'pp_data',subject,fit_model,'fit',base_file_name + '_est_%s_to_%s.nii' %(str(int(start_idx[iter_job])),str(int(end_idx[iter_job]))))


    if os.path.isfile(opfn):
        if os.path.getsize(opfn) != 0:
            print('output file %s already exists and is non-empty. aborting analysis of voxels %s to %s'%(opfn,str(int(start_idx[iter_job])),str(int(end_idx[iter_job]))))
            continue
            
    # create job shell
    jobscript = open(jobscript_template_file)
    working_string = jobscript.read()
    jobscript.close()
    job_dur = '%i:00:00'%job_dur_req
    
    re_dict = { '---job_dur---':job_dur,
                '---fit_file---':fit_script,
                '---fit_model---':fit_model,
                '---subject---':subject,
                '---start_idx---':str(int(start_idx[iter_job])),
                '---end_idx---':str(int(end_idx[iter_job])),
                '---data_file---':data_file[0],
                '---base_dir---':base_dir}

    for e in re_dict.keys():
        working_string  =   working_string.replace(e, re_dict[e])

    js_name =  opj(base_dir, 'pp_data', subject, fit_model, 'jobs', '%s_vox_%s_to_%s.sh'%(subject,str(int(start_idx[iter_job])),str(int(end_idx[iter_job]))))

    of = open(js_name, 'w')
    of.write(working_string)
    of.close()

    # Submit jobs
    print('submitting ' + js_name + ' to queue')

    if 'lisa' in platform.uname()[1]:
        os.chdir(opj(base_dir,'pp_data',subject,fit_model,'log_outputs'))
        os.system('qsub ' + js_name)

    elif 'aeneas' in platform.uname()[1]:
        os.system('sh ' + js_name)
        
    elif 'local' in platform.uname()[1]:
        os.system('sh ' + js_name)
# Out:
# 69 jobs of 10.0h each will be run/send to macbook-mbp.home
# input data vox num: 0 to 2500
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_0_to_2500.sh to queue
# input data vox num: 2500 to 5000
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_2500_to_5000.sh to queue
# input data vox num: 5000 to 7500
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_5000_to_7500.sh to queue
# input data vox num: 7500 to 10000
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_7500_to_10000.sh to queue
# input data vox num: 10000 to 12500
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_10000_to_12500.sh to queue
# input data vox num: 12500 to 15000
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_12500_to_15000.sh to queue
# input data vox num: 15000 to 17500
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_15000_to_17500.sh to queue
# input data vox num: 17500 to 20000
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_17500_to_20000.sh to queue
# input data vox num: 20000 to 22500
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_20000_to_22500.sh to queue
# input data vox num: 22500 to 25000
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_22500_to_25000.sh to queue
# input data vox num: 25000 to 27500
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_25000_to_27500.sh to queue
# input data vox num: 27500 to 30000
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_27500_to_30000.sh to queue
# input data vox num: 30000 to 32500
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_30000_to_32500.sh to queue
# input data vox num: 32500 to 35000
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_32500_to_35000.sh to queue
# input data vox num: 35000 to 37500
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_35000_to_37500.sh to queue
# input data vox num: 37500 to 40000
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_37500_to_40000.sh to queue
# input data vox num: 40000 to 42500
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_40000_to_42500.sh to queue
# input data vox num: 42500 to 45000
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_42500_to_45000.sh to queue
# input data vox num: 45000 to 47500
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_45000_to_47500.sh to queue
# input data vox num: 47500 to 50000
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_47500_to_50000.sh to queue
# input data vox num: 50000 to 52500
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_50000_to_52500.sh to queue
# input data vox num: 52500 to 55000
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_52500_to_55000.sh to queue
# input data vox num: 55000 to 57500
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_55000_to_57500.sh to queue
# input data vox num: 57500 to 60000
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_57500_to_60000.sh to queue
# input data vox num: 60000 to 62500
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_60000_to_62500.sh to queue
# input data vox num: 62500 to 65000
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_62500_to_65000.sh to queue
# input data vox num: 65000 to 67500
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_65000_to_67500.sh to queue
# input data vox num: 67500 to 70000
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_67500_to_70000.sh to queue
# input data vox num: 70000 to 72500
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_70000_to_72500.sh to queue
# input data vox num: 72500 to 75000
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_72500_to_75000.sh to queue
# input data vox num: 75000 to 77500
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_75000_to_77500.sh to queue
# input data vox num: 77500 to 80000
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_77500_to_80000.sh to queue
# input data vox num: 80000 to 82500
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_80000_to_82500.sh to queue
# input data vox num: 82500 to 85000
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_82500_to_85000.sh to queue
# input data vox num: 85000 to 87500
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_85000_to_87500.sh to queue
# input data vox num: 87500 to 90000
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_87500_to_90000.sh to queue
# input data vox num: 90000 to 92500
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_90000_to_92500.sh to queue
# input data vox num: 92500 to 95000
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_92500_to_95000.sh to queue
# input data vox num: 95000 to 97500
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_95000_to_97500.sh to queue
# input data vox num: 97500 to 100000
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_97500_to_100000.sh to queue
# input data vox num: 100000 to 102500
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_100000_to_102500.sh to queue
# input data vox num: 102500 to 105000
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_102500_to_105000.sh to queue
# input data vox num: 105000 to 107500
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_105000_to_107500.sh to queue
# input data vox num: 107500 to 110000
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_107500_to_110000.sh to queue
# input data vox num: 110000 to 112500
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_110000_to_112500.sh to queue
# input data vox num: 112500 to 115000
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_112500_to_115000.sh to queue
# input data vox num: 115000 to 117500
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_115000_to_117500.sh to queue
# input data vox num: 117500 to 120000
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_117500_to_120000.sh to queue
# input data vox num: 120000 to 122500
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_120000_to_122500.sh to queue
# input data vox num: 122500 to 125000
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_122500_to_125000.sh to queue
# input data vox num: 125000 to 127500
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_125000_to_127500.sh to queue
# input data vox num: 127500 to 130000
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_127500_to_130000.sh to queue
# input data vox num: 130000 to 132500
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_130000_to_132500.sh to queue
# input data vox num: 132500 to 135000
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_132500_to_135000.sh to queue
# input data vox num: 135000 to 137500
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_135000_to_137500.sh to queue
# input data vox num: 137500 to 140000
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_137500_to_140000.sh to queue
# input data vox num: 140000 to 142500
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_140000_to_142500.sh to queue
# input data vox num: 142500 to 145000
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_142500_to_145000.sh to queue
# input data vox num: 145000 to 147500
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_145000_to_147500.sh to queue
# input data vox num: 147500 to 150000
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_147500_to_150000.sh to queue
# input data vox num: 150000 to 152500
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_150000_to_152500.sh to queue
# input data vox num: 152500 to 155000
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_152500_to_155000.sh to queue
# input data vox num: 155000 to 157500
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_155000_to_157500.sh to queue
# input data vox num: 157500 to 160000
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_157500_to_160000.sh to queue
# input data vox num: 160000 to 162500
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_160000_to_162500.sh to queue
# input data vox num: 162500 to 165000
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_162500_to_165000.sh to queue
# input data vox num: 165000 to 167500
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_165000_to_167500.sh to queue
# input data vox num: 167500 to 170000
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_167500_to_170000.sh to queue
# input data vox num: 170000 to 170494
# submitting /Users/macbook/disks/ae_Home/projects/retino_HCP/pp_data/999999/gauss/jobs/999999_vox_170000_to_170494.sh to queue
